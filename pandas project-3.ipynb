# %% [markdown]
# ADULT INCOME DATASET

# %% [markdown]
# First we load the dataset into this

# %%
import pandas as pd
import matplotlib as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\gnane\Downloads\archive (4)\adult.csv")
df
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %% [markdown]
# 1.Display Top 10 Rows of The Dataset

# %%
df.head(10)
# Out:
#    age         workclass  fnlwgt     education  educational-num  \
# 0   25           Private  226802          11th                7
# 1   38           Private   89814       HS-grad                9
# 2   28         Local-gov  336951    Assoc-acdm               12
# 3   44           Private  160323  Some-college               10
# 4   18                 ?  103497  Some-college               10
# 5   34           Private  198693          10th                6
# 6   29                 ?  227026       HS-grad                9
# 7   63  Self-emp-not-inc  104626   Prof-school               15
# 8   24           Private  369667  Some-college               10
# 9   55           Private  104996       7th-8th                4
#
#        marital-status         occupation   relationship   race  gender  \
# 0       Never-married  Machine-op-inspct      Own-child  Black    Male
# 1  Married-civ-spouse    Farming-fishing        Husband  White    Male
# ...

# %% [markdown]
# 2. Check Last 10 Rows of The Dataset

# %%
df.tail(10)
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 48832   32       Private   34066          10th                6
# 48833   43       Private   84661     Assoc-voc               11
# 48834   32       Private  116138       Masters               14
# 48835   53       Private  321865       Masters               14
# 48836   22       Private  310152  Some-college               10
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation   relationship  \
# 48832  Married-civ-spouse  Handlers-cleaners        Husband
# 48833  Married-civ-spouse              Sales        Husband
# 48834       Never-married       Tech-support  Not-in-family
# ...

# %% [markdown]
# 3. Find Shape of Our Dataset (Number of Rows And Number of Columns)

# %%
df.shape
# Out:
# (48842, 15)

# %%
print('No of rows',df.shape[0])
print('No of columns',df.shape[1])
# Out:
# No of rows 48842
# No of columns 15

# %% [markdown]
# 4. Getting Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48842 non-null  int64
#  1   workclass        48842 non-null  object
#  2   fnlwgt           48842 non-null  int64
#  3   education        48842 non-null  object
#  4   educational-num  48842 non-null  int64
#  5   marital-status   48842 non-null  object
#  6   occupation       48842 non-null  object
#  7   relationship     48842 non-null  object
#  8   race             48842 non-null  object
#  9   gender           48842 non-null  object
#  10  capital-gain     48842 non-null  int64
#  11  capital-loss     48842 non-null  int64
#  12  hours-per-week   48842 non-null  int64
#  13  native-country   48842 non-null  object
#  14  income           48842 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB

# %% [markdown]
# 5. Fetch Random Sample From the Dataset (50%)

# %%
df.sample(frac=0.50) # to fetch any random data
# Out:
#        age  workclass  fnlwgt     education  educational-num  \
# 13005   55    Private  147989  Some-college               10
# 8528    46    Private  193188       Masters               14
# 13884   36    Private  174242     Bachelors               13
# 36208   55    Private  143266       HS-grad                9
# 8042    61    Private   29797       HS-grad                9
# ...    ...        ...     ...           ...              ...
# 5350    29    Private  182676          10th                6
# 45574   46    Private  220124       HS-grad                9
# 9702    24    Private  204244           9th                5
# 2403    22  Local-gov  326283  Some-college               10
# 1309    62    Private  101582       7th-8th                4
#
#            marital-status         occupation    relationship  \
# 13005  Married-civ-spouse       Craft-repair         Husband
# 8528        Never-married    Exec-managerial       Unmarried
# ...

# %% [markdown]
# 6..Check Null Values In The Dataset

# %%
df.isnull().sum(axis=1) # it is shows null values row-wise
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 48837    0
# 48838    0
# 48839    0
# 48840    0
# 48841    0
# Length: 48842, dtype: int64

# %%
df.isnull().sum(axis=0)# it shows null values column-wise
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# 7.Perform Data Cleaning [ Replace '?' with NaN ]

# %%
df.isin(['?']).sum() # first check how many '?' are there in data set
# Out:
# age                   0
# workclass          2799
# fnlwgt                0
# education             0
# educational-num       0
# marital-status        0
# occupation         2809
# relationship          0
# race                  0
# gender                0
# capital-gain          0
# capital-loss          0
# hours-per-week        0
# native-country      857
# income                0
# dtype: int64

# %%
import numpy as np
df['workclass']=df['workclass'].replace('?',np.nan)
df['occupation']=df['occupation'].replace('?',np.nan)
df['native-country']=df['native-country'].replace('?',np.nan)

# %%
df.isin(['?']).sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %% [markdown]
# 8.CHECK THE NULL VALUES

# %%
df.isnull().sum()
# Out:
# age                   0
# workclass          2799
# fnlwgt                0
# education             0
# educational-num       0
# marital-status        0
# occupation         2809
# relationship          0
# race                  0
# gender                0
# capital-gain          0
# capital-loss          0
# hours-per-week        0
# native-country      857
# income                0
# dtype: int64

# %%
sns.heatmap(df.isnull()) # to check null values with sns
# Out:
# <Axes: >

# %% [markdown]
# 8. Drop all The Missing Values

# %%
# drop missing values we can check missing values in data
df_missing=df.isnull().sum()*100/len(df)
df_missing
# Out:
# age                0.000000
# workclass          5.730724
# fnlwgt             0.000000
# education          0.000000
# educational-num    0.000000
# marital-status     0.000000
# occupation         5.751198
# relationship       0.000000
# race               0.000000
# gender             0.000000
# capital-gain       0.000000
# capital-loss       0.000000
# hours-per-week     0.000000
# native-country     1.754637
# income             0.000000
# dtype: float64

# %%
df.dropna(how='any',inplace=True)
df.isnull().sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %% [markdown]
#  9.Check For Duplicate Data and Drop Them

# %%
# first check duplicate values
df.duplicated().sum()
# Out:
# np.int64(47)

# %%
# Drop duplicate rows
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (45175, 15)

# %% [markdown]
# 10.GET OVERALL STATISTICS ABOUT DATA

# %%
df.describe()
# Out:
#                 age        fnlwgt  educational-num  capital-gain  \
# count  45175.000000  4.517500e+04     45175.000000  45175.000000
# mean      38.556170  1.897388e+05        10.119314   1102.576270
# std       13.215349  1.056524e+05         2.551740   7510.249876
# min       17.000000  1.349200e+04         1.000000      0.000000
# 25%       28.000000  1.173925e+05         9.000000      0.000000
# 50%       37.000000  1.783120e+05        10.000000      0.000000
# 75%       47.000000  2.379030e+05        13.000000      0.000000
# max       90.000000  1.490400e+06        16.000000  99999.000000
#
#        capital-loss  hours-per-week
# count  45175.000000    45175.000000
# mean      88.687593       40.942512
# std      405.156611       12.007730
# min        0.000000        1.000000
# 25%        0.000000       40.000000
# 50%        0.000000       40.000000
# 75%        0.000000       45.000000
# max     4356.000000       99.000000

# %% [markdown]
# 11. Drop The Columns education-num, capital-gain, and capital-loss

# %%
df.drop(['educational-num','capital-gain','capital-loss'],axis=1,inplace=True,errors='ignore')
df
# Out:
#        age     workclass  fnlwgt     education      marital-status  \
# 0       25       Private  226802          11th       Never-married
# 1       38       Private   89814       HS-grad  Married-civ-spouse
# 2       28     Local-gov  336951    Assoc-acdm  Married-civ-spouse
# 3       44       Private  160323  Some-college  Married-civ-spouse
# 5       34       Private  198693          10th       Never-married
# ...    ...           ...     ...           ...                 ...
# 48837   27       Private  257302    Assoc-acdm  Married-civ-spouse
# 48838   40       Private  154374       HS-grad  Married-civ-spouse
# 48839   58       Private  151910       HS-grad             Widowed
# 48840   22       Private  201490       HS-grad       Never-married
# 48841   52  Self-emp-inc  287927       HS-grad  Married-civ-spouse
#
#               occupation   relationship   race  gender  hours-per-week  \
# 0      Machine-op-inspct      Own-child  Black    Male              40
# ...

# %% [markdown]
# 12.UNIVARIATE ANALYSIS:analyze one variable at a time → summary + visualization.

# %%
df['age'].hist()
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt  # using histogram
df['age'].hist()
plt.title('Age Distribution')  
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
#  13.Find Total Number of Persons Having Age Between 17 To 48 (Inclusive) Using Between Method

# %%
sum(df['age'].between(17,48))
# Out:
# 34858

# %% [markdown]
# 14. What is The Distribution of Workclass Column?

# %%
df['workclass'].hist()
# Out:
# <Axes: >

# %%
# above graph is overlapping the data so we use below code

import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12,6))   # Increase width and height
sns.countplot(x='workclass', data=df)
plt.title('Workclass Distribution', fontsize=16)
plt.xlabel('Workclass', fontsize=12)
plt.ylabel('Frequency', fontsize=12)

plt.xticks(rotation=45)      # Rotate labels to avoid overlap
plt.grid(axis='y')           # Optional: horizontal gridlines


plt.show()

# %% [markdown]
# 15.How Many Persons Having Bachelors and Masters Degree?

# %%
df['education'].isin(['Bachelors','Masters']).sum()
# Out:
# np.int64(10072)

# %% [markdown]
# 16. Bivariate Analsis:Bivariate Analysis studies the relationship between two variables. It helps you understand if, how, and how strongly two variables are related.

# %% [markdown]
# NOW the realtion between age and salary

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(x='income', y='age', data=df,palette=['pink','red'])
plt.title('Age vs Salary Boxplot')
plt.show()
# Out:
# C:\Users\gnane\AppData\Local\Temp\ipykernel_1336\3910858516.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='income', y='age', data=df,palette=['pink','red'])

# %% [markdown]
# 17.Replace Salary Values With 0 and 1

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.countplot(x='income',data=df)
# Out:
# <Axes: xlabel='income', ylabel='count'>

# %%
#using titlenames,xaxis,y-axis names i.e 
import seaborn as sns
import matplotlib.pyplot as plt
sns.countplot(x='income', data=df)
plt.title('Income Count Plot')
plt.show()

# %%
# using custom colors like red,blue we use palette
import seaborn as sns
import matplotlib.pyplot as plt

# Count plot with custom colors
sns.countplot(x='income', data=df, palette=['blue', 'red'])
plt.title('Income Count Plot')
plt.show()
# Out:
# C:\Users\gnane\AppData\Local\Temp\ipykernel_1336\1003236602.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='income', data=df, palette=['blue', 'red'])

# %%
# Mapping '<=50K' to 0 and '>50K' to 1
df.replace(to_replace={'<=50K': 0, '>50K': 1}, inplace=True)
df
# Out:
#        age     workclass  fnlwgt     education      marital-status  \
# 0       25       Private  226802          11th       Never-married
# 1       38       Private   89814       HS-grad  Married-civ-spouse
# 2       28     Local-gov  336951    Assoc-acdm  Married-civ-spouse
# 3       44       Private  160323  Some-college  Married-civ-spouse
# 5       34       Private  198693          10th       Never-married
# ...    ...           ...     ...           ...                 ...
# 48837   27       Private  257302    Assoc-acdm  Married-civ-spouse
# 48838   40       Private  154374       HS-grad  Married-civ-spouse
# 48839   58       Private  151910       HS-grad             Widowed
# 48840   22       Private  201490       HS-grad       Never-married
# 48841   52  Self-emp-inc  287927       HS-grad  Married-civ-spouse
#
#               occupation   relationship   race  gender  hours-per-week  \
# 0      Machine-op-inspct      Own-child  Black    Male              40
# ...

# %% [markdown]
# 18. Which Workclass Getting The Highest Salary?

# %%
df.groupby('workclass')['income'].mean().sort_values(ascending=False)
# Out:
# workclass
# Self-emp-inc        0.554407
# Federal-gov         0.390469
# Local-gov           0.295161
# Self-emp-not-inc    0.279051
# State-gov           0.267215
# Private             0.217816
# Without-pay         0.095238
# Name: income, dtype: float64

# %% [markdown]
# 19.How Has Better Chance To Get Salary greater than 50K Male or Female?

# %%
df.groupby('gender')['income'].mean().sort_values(ascending=False)
# Out:
# gender
# Male      0.312609
# Female    0.113692
# Name: income, dtype: float64

# %% [markdown]
# 20.Covert workclass Columns Datatype To Category Datatype

# %%
# first we check workclass that is object 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45175 entries, 0 to 48841
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             45175 non-null  int64
#  1   workclass       45175 non-null  object
#  2   fnlwgt          45175 non-null  int64
#  3   education       45175 non-null  object
#  4   marital-status  45175 non-null  object
#  5   occupation      45175 non-null  object
#  6   relationship    45175 non-null  object
#  7   race            45175 non-null  object
#  8   gender          45175 non-null  object
#  9   hours-per-week  45175 non-null  int64
#  10  native-country  45175 non-null  object
#  11  income          45175 non-null  int64
# dtypes: int64(4), object(8)
# memory usage: 4.5+ MB

# %%
# now we convert into category data type
df['workclass']=df['workclass'].astype('category')

# %%
df.info()# here we have category data type in workclass
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45175 entries, 0 to 48841
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             45175 non-null  int64
#  1   workclass       45175 non-null  category
#  2   fnlwgt          45175 non-null  int64
#  3   education       45175 non-null  object
#  4   marital-status  45175 non-null  object
#  5   occupation      45175 non-null  object
#  6   relationship    45175 non-null  object
#  7   race            45175 non-null  object
#  8   gender          45175 non-null  object
#  9   hours-per-week  45175 non-null  int64
#  10  native-country  45175 non-null  object
#  11  income          45175 non-null  int64
# dtypes: category(1), int64(4), object(7)
# memory usage: 4.2+ MB
