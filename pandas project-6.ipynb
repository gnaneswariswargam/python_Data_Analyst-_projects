# %% [markdown]
# PROJECT-6: UDEMY COURSE DATASET

# %% [markdown]
# FIRST IMPORT THE DATA SET

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\gnane\Downloads\udemy_courses.csv",parse_dates=['published_timestamp'])
df
# above time and datacolumn i.e is published_timestamp is in object now we using prase_dates to convert objects into time &date
# Out:
#       course_id                                       course_title  \
# 0       1070968                 Ultimate Investment Banking Course
# 1       1113822  Complete GST Course & Certification - Grow You...
# 2       1006314  Financial Modeling for Business Analysts and C...
# 3       1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4       1011058       How To Maximize Your Profits Trading Options
# ...         ...                                                ...
# 3673     775618  Learn jQuery from Scratch - Master of JavaScri...
# 3674    1088178  How To Design A WordPress Website With No Codi...
# 3675     635248                      Learn and Build using Polymer
# 3676     905096  CSS Animations: Create Amazing Effects on Your...
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url  is_paid  price  \
# 0     https://www.udemy.com/ultimate-investment-bank...     True    200
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3678 entries, 0 to 3677
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3678 non-null   int64
#  1   course_title         3678 non-null   object
#  2   url                  3678 non-null   object
#  3   is_paid              3678 non-null   bool
#  4   price                3678 non-null   int64
#  5   num_subscribers      3678 non-null   int64
#  6   num_reviews          3678 non-null   int64
#  7   num_lectures         3678 non-null   int64
#  8   level                3678 non-null   object
#  9   content_duration     3678 non-null   float64
#  10  published_timestamp  3678 non-null   datetime64[ns, UTC]
#  11  subject              3678 non-null   object
# dtypes: bool(1), datetime64[ns, UTC](1), float64(1), int64(5), object(4)
# memory usage: 319.8+ KB

# %% [markdown]
# 1. Display Top 10 Rows of The Dataset

# %%
df.head(10)
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
# 5     192870  Trading Penny Stocks: A Guide for All Levels I...
# 6     739964  Investing And Trading For Beginners: Mastering...
# 7     403100  Trading Stock Chart Patterns For Immediate, Ex...
# 8     476268  Options Trading 3 : Advanced Stock Profit and ...
# 9    1167710  The Only Investment Strategy You Need For Your...
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# ...

# %% [markdown]
# 2. Check Last 5 Rows of The Dataset

# %%
df.tail(5)
# Out:
#       course_id                                       course_title  \
# 3673     775618  Learn jQuery from Scratch - Master of JavaScri...
# 3674    1088178  How To Design A WordPress Website With No Codi...
# 3675     635248                      Learn and Build using Polymer
# 3676     905096  CSS Animations: Create Amazing Effects on Your...
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url  is_paid  price  \
# 3673  https://www.udemy.com/easy-jquery-for-beginner...     True    100
# 3674  https://www.udemy.com/how-to-make-a-wordpress-...     True     25
# 3675  https://www.udemy.com/learn-and-build-using-po...     True     40
# 3676  https://www.udemy.com/css-animations-create-am...     True     50
# 3677  https://www.udemy.com/using-modx-cms-to-build-...     True     45
#
#       num_subscribers  num_reviews  num_lectures           level  \
# ...

# %% [markdown]
# 3. Find Shape of Our Dataset (Number of Rows And Number of Columns)

# %%
df.shape
# Out:
# (3678, 12)

# %%
print('no of rows',df.shape[0])
print('no of columns',df.shape[1])
# Out:
# no of rows 3678
# no of columns 12

# %% [markdown]
# 4. Getting Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3678 entries, 0 to 3677
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3678 non-null   int64
#  1   course_title         3678 non-null   object
#  2   url                  3678 non-null   object
#  3   is_paid              3678 non-null   bool
#  4   price                3678 non-null   int64
#  5   num_subscribers      3678 non-null   int64
#  6   num_reviews          3678 non-null   int64
#  7   num_lectures         3678 non-null   int64
#  8   level                3678 non-null   object
#  9   content_duration     3678 non-null   float64
#  10  published_timestamp  3678 non-null   datetime64[ns, UTC]
#  11  subject              3678 non-null   object
# dtypes: bool(1), datetime64[ns, UTC](1), float64(1), int64(5), object(4)
# memory usage: 319.8+ KB

# %% [markdown]
# 5. Check Null Values In The Dataset

# %%
df.isnull().sum()
# Out:
# course_id              0
# course_title           0
# url                    0
# is_paid                0
# price                  0
# num_subscribers        0
# num_reviews            0
# num_lectures           0
# level                  0
# content_duration       0
# published_timestamp    0
# subject                0
# dtype: int64

# %%
sns.heatmap(df.isnull())# there is no null values in our data set
# Out:
# <Axes: >

# %% [markdown]
# 6. Check For Duplicate Data and Drop Them

# %%
# first check duplicate values in data
duplicate_values=df.duplicated()
duplicate_values
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3673    False
# 3674    False
# 3675    False
# 3676    False
# 3677    False
# Length: 3678, dtype: bool

# %%
dup=df.drop_duplicates()

# %%
df.shape
# Out:
# (3678, 12)

# %% [markdown]
# 7. Find Out Number of Courses Per Subjects

# %%
df['subject'].value_counts()
# Out:
# subject
# Web Development        1200
# Business Finance       1195
# Musical Instruments     680
# Graphic Design          603
# Name: count, dtype: int64

# %%
# visual the data
sns.countplot(df['subject'])
# Out:
# <Axes: xlabel='count', ylabel='subject'>

# %% [markdown]
# * NOW THESE VISUAL ARE ARRANGE AS VERY NEATLY

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.Figure(figsize=(6,6))
sns.countplot(y=df['subject'],data=df,palette=['red','green','blue','orange'])
plt.title('Number of Courses Per Subjects')
plt.xlabel('subject')
plt.ylabel('count')
plt.show()
# Out:
# C:\Users\gnane\AppData\Local\Temp\ipykernel_13984\2271902936.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=df['subject'],data=df,palette=['red','green','blue','orange'])

# %% [markdown]
# 8. For Which Levels, Udemy Courses Providing The Courses

# %%
df['level'].value_counts()
# Out:
# level
# All Levels            1929
# Beginner Level        1270
# Intermediate Level     421
# Expert Level            58
# Name: count, dtype: int64

# %%
# we can visual this count plot
sns.countplot(y=df['level'],data=df,palette=['pink','yellow','brown','blue'])
# Out:
# C:\Users\gnane\AppData\Local\Temp\ipykernel_13984\3681794995.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=df['level'],data=df,palette=['pink','yellow','brown','blue'])
# <Axes: xlabel='count', ylabel='level'>

# %%
# to visual in neat way
plt.Figure(figsize=(6,6))
sns.countplot(y=df['level'],data=df,palette=['brown','black','orange','red'])
plt.title('No of Titles')
plt.xlabel('levels')
plt.ylabel('count')
plt.show()
# Out:
# C:\Users\gnane\AppData\Local\Temp\ipykernel_13984\825006862.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=df['level'],data=df,palette=['brown','black','orange','red'])

# %% [markdown]
# 9. Display The Count of Paid and Free Courses

# %%
df['is_paid'].value_counts()
# Out:
# is_paid
# True     3368
# False     310
# Name: count, dtype: int64

# %%
# for visual repersentation
sns.countplot(x=df['is_paid'],data=df,palette=['red','green'])
# Out:
# C:\Users\gnane\AppData\Local\Temp\ipykernel_13984\993252911.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df['is_paid'],data=df,palette=['red','green'])
# <Axes: xlabel='is_paid', ylabel='count'>

# %%
# to neatly repersentation
plt.Figure(figsize=(6,6))
sns.countplot(x=df['is_paid'],data=df,palette=['brown','black'])
plt.title('is_paid')
plt.xlabel('No of paid')
plt.ylabel('count')
plt.show()
# Out:
# C:\Users\gnane\AppData\Local\Temp\ipykernel_13984\989432698.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df['is_paid'],data=df,palette=['brown','black'])

# %% [markdown]
# 10. Which Course Has More Lectures (Free or Paid)?

# %%
df.groupby('is_paid')['num_lectures'].sum()
# Out:
# is_paid
# False      6639
# True     140881
# Name: num_lectures, dtype: int64

# %%
df
# Out:
#       course_id                                       course_title  \
# 0       1070968                 Ultimate Investment Banking Course
# 1       1113822  Complete GST Course & Certification - Grow You...
# 2       1006314  Financial Modeling for Business Analysts and C...
# 3       1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4       1011058       How To Maximize Your Profits Trading Options
# ...         ...                                                ...
# 3673     775618  Learn jQuery from Scratch - Master of JavaScri...
# 3674    1088178  How To Design A WordPress Website With No Codi...
# 3675     635248                      Learn and Build using Polymer
# 3676     905096  CSS Animations: Create Amazing Effects on Your...
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url  is_paid  price  \
# 0     https://www.udemy.com/ultimate-investment-bank...     True    200
# ...

# %% [markdown]
# 11. Which Courses Have A Higher Number of Subscribers Free or Paid?

# %%
df.groupby('is_paid')['num_subscribers'].sum()
# Out:
# is_paid
# False    3575525
# True     8183595
# Name: num_subscribers, dtype: int64

# %%
sns.barplot(x='is_paid',y='num_subscribers',data=df,palette=['yellow','red'])
# Out:
# C:\Users\gnane\AppData\Local\Temp\ipykernel_13984\3639002720.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='is_paid',y='num_subscribers',data=df,palette=['yellow','red'])
# <Axes: xlabel='is_paid', ylabel='num_subscribers'>

# %% [markdown]
# 12. Which Level Has The Highest Number of Subscribers?

# %%
df.groupby('level')['num_subscribers'].sum()
# Out:
# level
# All Levels            6915076
# Beginner Level        4051843
# Expert Level            50196
# Intermediate Level     742005
# Name: num_subscribers, dtype: int64

# %%
# to show visual repersention
plt.Figure(figsize=(6,6))
sns.barplot(x='level',y='num_subscribers',data=df,palette=['red','yellow','blue','brown'])
plt.title('Level Has The Highest Number of Subscribers')
plt.xlabel('level')
plt.ylabel('num_subscribers')
plt.show()
# Out:
# C:\Users\gnane\AppData\Local\Temp\ipykernel_13984\1352446028.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='level',y='num_subscribers',data=df,palette=['red','yellow','blue','brown'])

# %% [markdown]
# 13. Find Most Popular Course Title

# %%
df[df['num_subscribers'].max()==df['num_subscribers']]['course_title']
# Out:
# 2827    Learn HTML5 Programming From Scratch
# Name: course_title, dtype: object

# %% [markdown]
# 14. Display 10 Most Popular Courses As Per Number of Subscribers

# %%
top_10=df.sort_values(by='num_subscribers',ascending=False).head(10)
top_10
# Out:
#       course_id                                       course_title  \
# 2827      41295               Learn HTML5 Programming From Scratch
# 3032      59014                     Coding for Entrepreneurs Basic
# 3230     625204                         The Web Developer Bootcamp
# 2783     173548  Build Your First Website in 1 Week with HTML5 ...
# 3232     764164              The Complete Web Developer Course 2.0
# 1896      19421              Free Beginner Electric Guitar Lessons
# 2589     473160  Web Design for Web Developers: Build Beautiful...
# 2619      94430             Learn Javascript & JQuery From Scratch
# 3289     130064  Practical PHP: Master the Basics and Code Dyna...
# 3247     364426          JavaScript: Understanding the Weird Parts
#
#                                                     url  is_paid  price  \
# 2827  https://www.udemy.com/learn-html5-programming-...    False      0
# 3032  https://www.udemy.com/coding-for-entrepreneurs...    False      0
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Filter top 10
top_10 = df.sort_values(by='num_subscribers', ascending=False).head(10)

plt.figure(figsize=(10,6))  # bigger width so text fits

sns.barplot(x='num_subscribers', y='course_title', data=top_10, palette='Blues_r')

plt.title('Top 10 Most Popular Courses As Per Number of Subscribers')
plt.xlabel('Number of Subscribers')
plt.ylabel('Course Title')
plt.tight_layout()   # adjusts spacing
plt.show()
# Out:
# C:\Users\gnane\AppData\Local\Temp\ipykernel_13984\1897338986.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='num_subscribers', y='course_title', data=top_10, palette='Blues_r')

# %%
# per different colours
plt.figure(figsize=(12,6))

sns.barplot(
    x='num_subscribers',
    y='course_title',
    data=top_10,
    palette=sns.color_palette('tab10', 10)  # 10 distinct colors
)

plt.title('Top 10 Most Popular Courses As Per Number of Subscribers')
plt.xlabel('Number of Subscribers')
plt.ylabel('Course Title')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\gnane\AppData\Local\Temp\ipykernel_13984\2230595652.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %% [markdown]
# 15. Find The Course Which Is Having The Highest Number of Reviews.

# %%
# Group by subject and sum the number of reviews
subject_reviews = df.groupby('subject')['num_reviews'].sum()

# Find the subject with the maximum reviews
top_subject = subject_reviews.idxmax()
top_reviews = subject_reviews.max()

print(f"Subject with highest reviews: {top_subject} ({top_reviews} reviews)")
# Out:
# Subject with highest reviews: Web Development (430025 reviews)

# %%
top_course = df[df['num_reviews'] == df['num_reviews'].max()]
print(top_course)
# Out:
#       course_id                course_title  \
# 3230     625204  The Web Developer Bootcamp
#
#                                                     url  is_paid  price  \
# 3230  https://www.udemy.com/the-web-developer-bootcamp/     True    200
#
#       num_subscribers  num_reviews  num_lectures       level  \
# 3230           121584        27445           342  All Levels
#
#       content_duration       published_timestamp          subject
# 3230              43.0 2015-11-02 21:13:27+00:00  Web Development

# %%
# barplot visual
sns.barplot(x='subject',y='num_reviews',data=df)
# Out:
# <Axes: xlabel='subject', ylabel='num_reviews'>

# %%
# to visual neatly
import seaborn as sns
import matplotlib.pyplot as plt

# Set figure size
plt.figure(figsize=(10,6))

# Create barplot with palette for different colors
sns.barplot(
    x='subject',
    y='num_reviews',
    data=df,
    palette='Set3'  # You can use any seaborn palette or list of colors
)

# Add title and labels
plt.title('Number of Reviews per Subject', fontsize=16)
plt.xlabel('Subject', fontsize=12)
plt.ylabel('Number of Reviews', fontsize=12)

# Rotate x-axis labels if they overlap
plt.xticks(rotation=45)

# Show plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\gnane\AppData\Local\Temp\ipykernel_13984\1809726490.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %% [markdown]
# 16. Does Price Affect the Number of Reviews?

# %%
# Calculate correlation
correlation = df['price'].corr(df['num_reviews'])
print("Correlation between Price and Number of Reviews:", correlation)
# Out:
# Correlation between Price and Number of Reviews: 0.11369591938207214

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))
plt.scatter(df['price'], df['num_reviews'], alpha=0.6)
plt.xlabel('Price')
plt.ylabel('Number of Reviews')
plt.title('Price vs Number of Reviews')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))
plt.scatter(df['price'], df['num_reviews'], alpha=0.6)
plt.xlabel('Price')
plt.ylabel('Number of Reviews')
plt.title('Price vs Number of Reviews')
plt.show()

# %% [markdown]
# 17. Find Total Number of Courses Related To Python

# %%
len(df[df['course_title'].str.contains('python',case=False)])
# Out:
# 29

# %% [markdown]
# 18. Display 10 Most Popular Python Courses As Per Number of Subscribers

# %%
python=df[df['course_title'].str.contains('python',case=False)].sort_values(by='num_subscribers',ascending=False).head(10)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Filter top 10 Python courses
python_top10 = df[df['course_title'].str.contains('python', case=False)].sort_values(by='num_subscribers', ascending=False).head(10)

# Set figure size
plt.figure(figsize=(10,6))

# Barplot with different colors
sns.barplot(
    x='num_subscribers',
    y='course_title',
    data=python_top10,
    palette='Set2'  # You can change palette or provide custom colors
)

# Add title and labels
plt.title('Top 10 Python Courses by Number of Subscribers', fontsize=16)
plt.xlabel('Number of Subscribers', fontsize=12)
plt.ylabel('Course Title', fontsize=12)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\gnane\AppData\Local\Temp\ipykernel_13984\3317376449.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %% [markdown]
# 19. In Which Year The Highest Number of Courses Were Posted?

# %%
df['Year']=df['published_timestamp'].dt.year
df.head(1)
# Out:
#    course_id                        course_title  \
# 0    1070968  Ultimate Investment Banking Course
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
#
#    num_subscribers  num_reviews  num_lectures       level  content_duration  \
# 0             2147           23            51  All Levels               1.5
#
#         published_timestamp           subject  Year
# 0 2017-01-18 20:58:58+00:00  Business Finance  2017

# %%
# visually repersentation
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))

# Count number of courses per year
sns.countplot(x='Year', data=df, palette='Set3')

plt.title('Number of Courses Published Each Year', fontsize=16)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Number of Courses', fontsize=12)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\gnane\AppData\Local\Temp\ipykernel_13984\994734402.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Year', data=df, palette='Set3')

# %% [markdown]
# 20. Display Category-Wise Count of Posted Subjects [Year Wise]

# %%
df.groupby('Year')['subject'].value_counts()
# Out:
# Year  subject
# 2011  Web Development          5
# 2012  Web Development         19
#       Graphic Design          10
#       Musical Instruments     10
#       Business Finance         6
# 2013  Business Finance        84
#       Web Development         56
#       Musical Instruments     39
#       Graphic Design          23
# 2014  Business Finance       192
#       Musical Instruments    120
#       Web Development        113
#       Graphic Design          66
# 2015  Business Finance       339
#       Web Development        336
#       Musical Instruments    171
#       Graphic Design         168
# 2016  Web Development        448
#       Business Finance       349
#       Musical Instruments    228
#       Graphic Design         181
# 2017  Business Finance       225
#       Web Development        223
#       Graphic Design         155
#       Musical Instruments    112
# Name: count, dtype: int64
